# %%
import os
import sys
import datetime
import numpy as np
import matplotlib.pyplot as plt
import h5py

sys.path.insert(0, "../")

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from architectures.unet import UNet
from architectures.laddernet import LadderNet
from metrics.multiclass_dice import multiclass_dice
# Out:
# Traceback (most recent call last):
#
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-4973a021d19a>", line 14, in <module>
#     from architectures.unet import UNet
#
#   File "../architectures/unet.py", line 64
#     outputs = Activation("softmax")(x)
#           ^
# SyntaxError: invalid syntax

# %%
#%load_ext tensorboard

# %%
f = h5py.File("../data/preprocessed/image_dataset.hdf5", "r")

# %%
no_train = 158

train_image_subset = f["train images"][:no_train,:,:,0]
train_image_subset = train_image_subset.reshape([no_train, 384, 384, 1])

train_mask_subset = f["train masks"][:no_train,:,:,0]
train_mask_subset = train_mask_subset.reshape([no_train, 384, 384, 1])

# %%
no_val = 68

val_image_subset = f["validation images"][:no_val,:,:,0]
val_image_subset = val_image_subset.reshape([no_val, 384, 384, 1])

val_mask_subset = f["validation masks"][:no_val,:,:,0]
val_mask_subset = val_mask_subset.reshape([no_val, 384, 384, 1])

# %%
model_laddernet = LadderNet(input_size=(384,384,1), num_classes=4, filters=10)
model_unet = UNet(input_size=(384,384,1), depth=5, num_classes=4, filters=30, batch_norm=True)

# %%
earlystop = EarlyStopping(monitor='val_multiclass_dice', min_delta=0, patience=5, verbose=1, mode="max", restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor='val_multiclass_dice', factor=0.2, patience=2, verbose=1, mode="max", min_lr=1e-5)

# %%
model_laddernet.compile(optimizer=Adam(lr=1e-3), loss="sparse_categorical_crossentropy", metrics=[multiclass_dice])

# %%
history = model_laddernet.fit(x=train_image_subset,
                         y=train_mask_subset,
                         validation_data=(val_image_subset, val_mask_subset),
                         shuffle=True,
                         batch_size=1,
                         epochs=30,
                         callbacks=([earlystop, reduce_lr]))
# Out:
# Train on 158 samples, validate on 68 samples
# Epoch 1/30
#  15/158 [=>............................] - ETA: 3:47 - loss: 1.6136 - multiclass_dice: 0.1265WARNING:tensorflow:Early stopping conditioned on metric `val_multiclass_dice` which is not available. Available metrics are: loss,multiclass_dice
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_multiclass_dice` which is not available. Available metrics are: loss,multiclass_dice,lr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8ccc9c16fef9> in <module>
#       5                          batch_size=1,
#       6                          epochs=30,
# ----> 7                          callbacks=([earlystop, reduce_lr]))
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\util\nest.py in <listcomp>(.0)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in _non_none_constant_value(v)
#      90
#      91 def _non_none_constant_value(v):
# ---> 92   constant_value = tensor_util.constant_value(v)
#      93   return constant_value if constant_value is not None else v
#      94
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\framework\tensor_util.py in constant_value(tensor, partial)
#     790   """
#     791   if isinstance(tensor, ops.EagerTensor):
# --> 792     return tensor.numpy()
#     793   if not is_tensor(tensor):
#     794     return tensor
#
# D:\Alberto\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in numpy(self)
#     931       ValueError: if the type of this Tensor is not representable in numpy.
#     932     """
# --> 933     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     934     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     935
#
# KeyboardInterrupt:

# %%
plt.rcParams['figure.figsize'] = 10, 6
plt.plot(history.history['multiclass_dice'])
plt.plot(history.history['val_multiclass_dice'])
plt.ylabel('multiclass_dice')
plt.xlabel('epoch')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b40c84baeecf> in <module>
#       1 plt.rcParams['figure.figsize'] = 10, 6
# ----> 2 plt.plot(history.history['multiclass_dice'])
#       3 plt.plot(history.history['val_multiclass_dice'])
#       4 plt.ylabel('multiclass_dice')
#       5 plt.xlabel('epoch')
#
# NameError: name 'history' is not defined

# %%
prediction = model_unet.predict(val_image_subset[0:3,:,:,:])

# %%
prediction.shape
# Out:
# (3, 384, 384, 4)

# %%
import tensorflow as tf

# %%
z = tf.math.argmax(prediction, axis = 3)

# %%
plt.imshow(val_image_subset[6,:,:,0], cmap="bone")
plt.imshow(z[0,:,:], alpha=0.4)

# %%
plt.imshow(val_image_subset[6,:,:,0])

# %%
plt.imshow(val_mask_subset[6,:,:,0])

# %%
plt.imshow(z[0,:,:],vmin=0, vmax=3)
plt.show()

# %%
def get_patches(img_tensor, size=256, stride=128):
    '''
    Takes single image or array of images and returns
    crops using sliding window method.
    If stride < size it will do overlapping.
    '''
    img_arr = np.array(img_tensor)
    type(img_arr)
    img_arr.shape
    # check size and stride
    if size % stride != 0: 
        raise ValueError('size % stride must be equal 0')
        
        
    patches_list = []
    overlapping = 0    
    if stride != size:
        overlapping = (size // stride) - 1
    
    if img_arr.ndim == 3:    
        i_max = img_arr.shape[0] // stride-overlapping

        for i in range(i_max):
            for j in range(i_max):
                #print(i*stride, i*stride+size)
                #print(j*stride, j*stride+size)
                patches_list.append(
                    img_arr[i*stride:i*stride+size,
                            j*stride:j*stride+size
                           ])
                
    elif img_arr.ndim == 4:
        i_max = img_arr.shape[1] // stride - overlapping
        for im in img_arr:
            for i in range(i_max):
                for j in range(i_max):
                    #print(i*stride, i*stride+size)
                    #print(j*stride, j*stride+size)
                    patches_list.append(
                        im[i*stride:i*stride+size,
                           j*stride:j*stride+size
                          ])
                    
    else:
        raise ValueError('img_arr.ndim must be equal 3 or 4')
    
    return np.array(patches_list)

# %%
from sklearn.feature_extraction import image
patches = image.extract_patches_2d(z[0,:,:], (128, 128))

# %%
z.shape
# Out:
# TensorShape([3, 384, 384])

# %%
patches.shape
# Out:
# (103041, 64, 64)

# %%
plt.imshow(patches[0,:,:])

# %%
reimage = image.reconstruct_from_patches_2d(patches, (384, 384))

# %%
plt.imshow(reimage)

# %%
reimage.shape
# Out:
# (384, 384)
