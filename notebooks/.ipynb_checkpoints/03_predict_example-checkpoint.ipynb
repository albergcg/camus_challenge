# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import h5py
from keras.utils import plot_model

sys.path.insert(0, "../")
#import laddernet
from models.laddernet import LadderNet
from models.unet import UNet
# Out:
# Using TensorFlow backend.

# %%
f = h5py.File("../data/preprocessed/image_dataset.hdf5", "r")
example = f["train images"][2,:,:,0]
example = example.reshape([1, 384, 384, 1])
example.shape
# Out:
# (1, 384, 384, 1)

# %%
#model_laddernet = LadderNet(input_size=(384, 384, 1), num_classes=4)
model_unet = UNet(input_size=(384, 384, 1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9a7c01b6030f> in <module>
#       1 #model_laddernet = LadderNet(input_size=(384, 384, 1), num_classes=4)
# ----> 2 model_unet = UNet(input_size=(384, 384, 1))
#
# TypeError: UNet() missing 4 required positional arguments: 'depth', 'num_classes', 'filters', and 'initial_rate'

# %%
plot_model(model_unet)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-7b2f692f1776> in <module>
# ----> 1 plot_model(model_unet)
#
# D:\Alberto\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\utils\vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     238     """
#     239     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir,
# --> 240                        expand_nested, dpi)
#     241     _, extension = os.path.splitext(to_file)
#     242     if not extension:
#
# D:\Alberto\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\utils\vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#      77     from ..models import Sequential
#      78
# ---> 79     _check_pydot()
#      80     if subgraph:
# ...

# %%
plot_model(model_laddernet)

# %%
model_laddernet.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 384, 384, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 384, 384, 10) 100         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 384, 384, 10) 910         conv2d_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 384, 384, 10) 40          conv2d_2[0][0]
# __________________________________________________________________________________________________
# ...

# %%
plt.imshow(example[0,:,:,0])
plt.show()

# %%
x = model_laddernet.predict(example)
y = model_unet.predict(example)

# %%
plt.imshow(x[0,:,:,0])
plt.show()

# %%
plt.imshow(y[0,:,:,0])
plt.show()

# %%
x.shape
# Out:
# (1, 384, 384, 4)
