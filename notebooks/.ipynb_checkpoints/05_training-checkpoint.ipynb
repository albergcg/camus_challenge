# %%
# Standard
import os
import sys
import datetime
import numpy as np
import matplotlib.pyplot as plt

# Utils
import h5py

# Deep Learning
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

# User defined
sys.path.insert(0, "../")
from architectures.laddernet import LadderNet
from architectures.unet import UNet
from metrics.multiclass_dice import multiclass_dice

# %%
f = h5py.File("../../data/image_dataset.hdf5", "r")

# %%
frames2ch = f["train 2ch frames"][:,:,:,:]
masks2ch = f["train 2ch masks"][:,:,:,:]

# %%
train_frames, test_frames, train_masks, test_masks = train_test_split(frames2ch, masks2ch)

# %%
# Out:
# (225, 384, 384, 1)

# %%
model_laddernet = LadderNet(input_size=(384, 384, 1), num_classes=4, filters=20)
model_unet = UNet(input_size=(384, 384, 1), depth=5, num_classes=4, filters=10, batch_norm=True)

# %%
earlystop = EarlyStopping(monitor='val_multiclass_dice', min_delta=0, patience=5, verbose=1, mode="max", restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor='val_multiclass_dice', factor=0.2, patience=2, verbose=1, mode="max", min_lr=1e-5)

# %%
model_laddernet.compile(optimizer=Adam(lr=1e-3), loss="sparse_categorical_crossentropy", metrics=[multiclass_dice, "accuracy"])

# %%
model_laddernet.fit(x=train_frames,
                    y=train_masks,
                    validation_data=[test_frames, test_masks],
                    batch_size=5,
                    epochs=150,
                    callbacks=[earlystop, reduce_lr])
# Out:
# Train on 675 samples, validate on 225 samples
# Epoch 1/150
# 675/675 [==============================] - 153s 227ms/sample - loss: 0.6765 - multiclass_dice: 0.4816 - accuracy: 0.7861 - val_loss: 11.8425 - val_multiclass_dice: 0.2777 - val_accuracy: 0.2060
# Epoch 2/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.2815 - multiclass_dice: 0.7226 - accuracy: 0.9005 - val_loss: 2.6436 - val_multiclass_dice: 0.4709 - val_accuracy: 0.7093
# Epoch 3/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.2446 - multiclass_dice: 0.7520 - accuracy: 0.9096 - val_loss: 2.2660 - val_multiclass_dice: 0.4535 - val_accuracy: 0.6022
# Epoch 4/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.2086 - multiclass_dice: 0.7849 - accuracy: 0.9211 - val_loss: 0.3720 - val_multiclass_dice: 0.7532 - val_accuracy: 0.9001
# Epoch 5/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1862 - multiclass_dice: 0.8066 - accuracy: 0.9288 - val_loss: 0.2659 - val_multiclass_dice: 0.7753 - val_accuracy: 0.9142
# Epoch 6/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1728 - multiclass_dice: 0.8200 - accuracy: 0.9336 - val_loss: 0.2293 - val_multiclass_dice: 0.8043 - val_accuracy: 0.9252
# Epoch 7/150
# 675/675 [==============================] - 143s 212ms/sample - loss: 0.1606 - multiclass_dice: 0.8309 - accuracy: 0.9374 - val_loss: 0.1849 - val_multiclass_dice: 0.7984 - val_accuracy: 0.9301
# Epoch 8/150
# 670/675 [============================>.] - ETA: 0s - loss: 0.1543 - multiclass_dice: 0.8374 - accuracy: 0.9397
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1541 - multiclass_dice: 0.8373 - accuracy: 0.9397 - val_loss: 0.1797 - val_multiclass_dice: 0.7981 - val_accuracy: 0.9295
# Epoch 9/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1317 - multiclass_dice: 0.8579 - accuracy: 0.9474 - val_loss: 0.1415 - val_multiclass_dice: 0.8437 - val_accuracy: 0.9444
# Epoch 10/150
# 675/675 [==============================] - 143s 213ms/sample - loss: 0.1254 - multiclass_dice: 0.8638 - accuracy: 0.9498 - val_loss: 0.1376 - val_multiclass_dice: 0.8436 - val_accuracy: 0.9448
# Epoch 11/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1217 - multiclass_dice: 0.8668 - accuracy: 0.9508 - val_loss: 0.1364 - val_multiclass_dice: 0.8447 - val_accuracy: 0.9453
# Epoch 12/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1198 - multiclass_dice: 0.8686 - accuracy: 0.9514 - val_loss: 0.1297 - val_multiclass_dice: 0.8571 - val_accuracy: 0.9488
# Epoch 13/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1182 - multiclass_dice: 0.8707 - accuracy: 0.9520 - val_loss: 0.1327 - val_multiclass_dice: 0.8559 - val_accuracy: 0.9472
# Epoch 14/150
# 670/675 [============================>.] - ETA: 0s - loss: 0.1151 - multiclass_dice: 0.8739 - accuracy: 0.9532
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1153 - multiclass_dice: 0.8737 - accuracy: 0.9532 - val_loss: 0.1288 - val_multiclass_dice: 0.8534 - val_accuracy: 0.9483
# Epoch 15/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1092 - multiclass_dice: 0.8803 - accuracy: 0.9556 - val_loss: 0.1220 - val_multiclass_dice: 0.8627 - val_accuracy: 0.9512
# Epoch 16/150
# 675/675 [==============================] - 143s 213ms/sample - loss: 0.1072 - multiclass_dice: 0.8818 - accuracy: 0.9562 - val_loss: 0.1197 - val_multiclass_dice: 0.8690 - val_accuracy: 0.9522
# Epoch 17/150
# 675/675 [==============================] - 143s 212ms/sample - loss: 0.1062 - multiclass_dice: 0.8827 - accuracy: 0.9564 - val_loss: 0.1189 - val_multiclass_dice: 0.8690 - val_accuracy: 0.9526
# Epoch 18/150
# 670/675 [============================>.] - ETA: 0s - loss: 0.1064 - multiclass_dice: 0.8829 - accuracy: 0.9566
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1e-05.
# 675/675 [==============================] - 143s 213ms/sample - loss: 0.1066 - multiclass_dice: 0.8827 - accuracy: 0.9565 - val_loss: 0.1197 - val_multiclass_dice: 0.8665 - val_accuracy: 0.9522
# Epoch 19/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1045 - multiclass_dice: 0.8849 - accuracy: 0.9572 - val_loss: 0.1180 - val_multiclass_dice: 0.8704 - val_accuracy: 0.9530
# Epoch 20/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1039 - multiclass_dice: 0.8850 - accuracy: 0.9574 - val_loss: 0.1184 - val_multiclass_dice: 0.8706 - val_accuracy: 0.9529
# Epoch 21/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1047 - multiclass_dice: 0.8846 - accuracy: 0.9573 - val_loss: 0.1183 - val_multiclass_dice: 0.8708 - val_accuracy: 0.9530
# Epoch 22/150
# 675/675 [==============================] - 143s 213ms/sample - loss: 0.1038 - multiclass_dice: 0.8857 - accuracy: 0.9575 - val_loss: 0.1179 - val_multiclass_dice: 0.8707 - val_accuracy: 0.9531
# Epoch 23/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1032 - multiclass_dice: 0.8863 - accuracy: 0.9577 - val_loss: 0.1179 - val_multiclass_dice: 0.8712 - val_accuracy: 0.9531
# Epoch 24/150
# 675/675 [==============================] - 143s 212ms/sample - loss: 0.1033 - multiclass_dice: 0.8863 - accuracy: 0.9577 - val_loss: 0.1179 - val_multiclass_dice: 0.8708 - val_accuracy: 0.9532
# Epoch 25/150
# 675/675 [==============================] - 143s 212ms/sample - loss: 0.1026 - multiclass_dice: 0.8870 - accuracy: 0.9580 - val_loss: 0.1182 - val_multiclass_dice: 0.8707 - val_accuracy: 0.9531
# Epoch 26/150
# 675/675 [==============================] - 143s 213ms/sample - loss: 0.1029 - multiclass_dice: 0.8864 - accuracy: 0.9578 - val_loss: 0.1183 - val_multiclass_dice: 0.8705 - val_accuracy: 0.9531
# Epoch 27/150
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1026 - multiclass_dice: 0.8872 - accuracy: 0.9579 - val_loss: 0.1180 - val_multiclass_dice: 0.8712 - val_accuracy: 0.9532
# Epoch 28/150
# 670/675 [============================>.] - ETA: 0s - loss: 0.1037 - multiclass_dice: 0.8860 - accuracy: 0.9576Restoring model weights from the end of the best epoch.
# 675/675 [==============================] - 144s 213ms/sample - loss: 0.1036 - multiclass_dice: 0.8861 - accuracy: 0.9576 - val_loss: 0.1182 - val_multiclass_dice: 0.8711 - val_accuracy: 0.9532
# Epoch 00028: early stopping

# %%
plot_model(model_unet)
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
model_unet

# %%
plt.imshow(train_image_subset[0,:,:,0])

# %%
plt.imshow(train_mask_subset[0,:,:,0])

# %%
prediction = model_laddernet.predict(train_image_subset[:1,:,:,:])

# %%
prediction = prediction.reshape([384, 384, 4])
prediction.shape
# Out:
# (384, 384, 4)

# %%
import tensorflow as tf

# %%
y = tf.convert_to_tensor(prediction)

# %%
z = tf.math.argmax(prediction, axis = 2)

# %%
plt.imshow(train_image_subset[0,:,:,0])

# %%
plt.imshow(train_mask_subset[0,:,:,0])

# %%
z.shape

# %%
plt.imshow(z[:,:])
plt.show()

# %%
val_mask_subset[0,300,205,0]

# %%
model_laddernet.save_weights("../")
